# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (7, 4)
plt.style.use('default')
plt.rcParams['figure.figsize'] = (12, 8)

# %%
df = pd.read_csv("D:\\PROGRAMMING\\DATASETS\\NonLinear.csv")
print(df.shape)
df.head()
# Out:
# (1000, 6)
#           x1        x2          x3           x4        x5            y
# 0  14.478781  5.112410  552.705650  7888.926227  1.543017  8466.847538
# 1  30.088938  4.840943  572.214467  8938.384509  0.717611  9553.683909
# 2  19.859499  5.296732   28.479466  3019.026376  1.656855  3123.311226
# 3  52.113635  5.198067   64.392542  7874.777140  0.500326  8014.576231
# 4  51.449099  4.767765  599.762702  2381.280604  0.509556  3056.833882

# %%
## Dependent / Independent variables 
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
c = list(X.columns)

# %%
sb.pairplot(df, x_vars=c, y_vars='y', kind='scatter')

# %%
# def poly_reg(d):
#     polyreg = PolynomialFeatures(degree=d)
#     X_poly = polyreg.fit_transform(X)

#     ## Train Test Split
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

#     linreg = LinearRegression()
#     linreg.fit(X_train, y_train)

#     y_train_predict = linreg.predict(X_train)
#     y_test_predict = linreg.predict(X_test)

#     sorted_indices_train = np.argsort(y_train)
#     sb.pairplot(data=df, x_vars=X, y_vars=y)
#     plt.plot(X, linreg.predict(X), color='r', label='Fitted Curve')
#     plt.xlabel('Actual Values')
#     plt.ylabel('Predicted Values')
#     plt.title('Polynomial Regression - Training')
#     plt.legend()
#     plt.grid(True)
#     plt.show()
