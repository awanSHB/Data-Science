# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
plt.style.use('default')
plt.rcParams["figure.figsize"] = (10, 6)
import seaborn as sb

# %%
df = pd.read_csv("D:\PROGRAMMING\Datasets\polydata.csv")
df
# Out:
#              Position  Level   Salary
# 0   Business\nAnalyst      1    45000
# 1  Junior\nConsultant      2    50000
# 2   Senior Consultant      3    60000
# 3             Manager      4    80000
# 4    Country\nManager      5   110000
# 5     Region\nManager      6   150000
# 6             Partner      7   200000
# 7     Senior\nPartner      8   300000
# 8           C - level      9   500000
# 9                 CEO     10  1000000

# %%
## Dependent / Independent Variable
X = df.iloc[:, 1:2]
y = df.iloc[:, 2]

# %%
## Fitting the model
linreg = LinearRegression()
linreg.fit(X, y)
# Out:
# LinearRegression()

# %%
## Polynomial fitting
polyreg = PolynomialFeatures(degree=2)
x_poly = polyreg.fit_transform(X)
linreg2 = LinearRegression()
linreg2.fit(x_poly, y)
y_predict = linreg2.predict(x_poly)
print(x_poly)
# Out:
# [[  1.   1.   1.]
#  [  1.   2.   4.]
#  [  1.   3.   9.]
#  [  1.   4.  16.]
#  [  1.   5.  25.]
#  [  1.   6.  36.]
#  [  1.   7.  49.]
#  [  1.   8.  64.]
#  [  1.   9.  81.]
#  [  1.  10. 100.]]

# %%
## Coefficients
b0, b1, b2 = linreg2.coef_[0:]
print("b0 : ", b0)
print("b1 : ", b1)
print("b2 : ", b2)
# Out:
# b0 :  0.0
# b1 :  -132871.21212121213
# b2 :  19431.81818181819

# %%
v = list(df["Salary"].values)
plt.scatter(X, y, color = "blue")
plt.plot(X, linreg.predict(X), color = "red")
plt.title("Linear Regression")
plt.xlabel("Position Levels")
plt.ylabel("Salary")
plt.grid()
plt.show()

# %%
## For Polynomial regression
plt.scatter(X, y, color = "blue")
plt.plot(X, y_predict, color = "red")
plt.title("Polynomial Regression")
plt.ylabel("Salary")
plt.xlabel("Position Levels")
plt.grid()
plt.show()

# %% [markdown]
# <h1>Degree = 3</h1>

# %%
polyreg = PolynomialFeatures(degree=3)
x_poly = polyreg.fit_transform(X)
linreg2 = LinearRegression()
linreg2.fit(x_poly, y)
y_predict = linreg2.predict(x_poly)
print(x_poly)
# Out:
# [[   1.    1.    1.    1.]
#  [   1.    2.    4.    8.]
#  [   1.    3.    9.   27.]
#  [   1.    4.   16.   64.]
#  [   1.    5.   25.  125.]
#  [   1.    6.   36.  216.]
#  [   1.    7.   49.  343.]
#  [   1.    8.   64.  512.]
#  [   1.    9.   81.  729.]
#  [   1.   10.  100. 1000.]]

# %%
## Coefficients
b0, b1, b2, b3 = linreg2.coef_[0:]
print("b0 : ", b0)
print("b1 : ", b1)
print("b2 : ", b2)
print("b3 : ", b3)
# Out:
# b0 :  0.0
# b1 :  180664.33566431512
# b2 :  -48548.95104894672
# b3 :  4120.046620046342

# %%
plt.scatter(X, y, color = "blue")
plt.plot(X, y_predict, color = "red")
plt.title("Polynomial Regression")
plt.ylabel("Salary")
plt.xlabel("Position Levels")
plt.grid()
plt.show()

# %% [markdown]
# <h1>Degree = 4</h1>

# %%
polyreg = PolynomialFeatures(degree=4)
x_poly = polyreg.fit_transform(X)
linreg2 = LinearRegression()
linreg2.fit(x_poly, y)
y_predict = linreg2.predict(x_poly)
print(x_poly)
# Out:
# [[1.000e+00 1.000e+00 1.000e+00 1.000e+00 1.000e+00]
#  [1.000e+00 2.000e+00 4.000e+00 8.000e+00 1.600e+01]
#  [1.000e+00 3.000e+00 9.000e+00 2.700e+01 8.100e+01]
#  [1.000e+00 4.000e+00 1.600e+01 6.400e+01 2.560e+02]
#  [1.000e+00 5.000e+00 2.500e+01 1.250e+02 6.250e+02]
#  [1.000e+00 6.000e+00 3.600e+01 2.160e+02 1.296e+03]
#  [1.000e+00 7.000e+00 4.900e+01 3.430e+02 2.401e+03]
#  [1.000e+00 8.000e+00 6.400e+01 5.120e+02 4.096e+03]
#  [1.000e+00 9.000e+00 8.100e+01 7.290e+02 6.561e+03]
#  [1.000e+00 1.000e+01 1.000e+02 1.000e+03 1.000e+04]]

# %%
## Coefficients
b0, b1, b2, b3, b4 = linreg2.coef_[0:]
print("b0 : ", b0)
print("b1 : ", b1)
print("b2 : ", b2)
print("b3 : ", b3)
print("b4 : ", b4)
# Out:
# b0 :  0.0
# b1 :  -211002.33100291895
# b2 :  94765.44289063042
# b3 :  -15463.286713309728
# b4 :  890.15151515248

# %%
plt.scatter(X, y, color = "blue")
plt.plot(X, y_predict, color = "red")
plt.title("Polynomial Regression")
plt.ylabel("Salary")
plt.xlabel("Position Levels")
plt.grid()
plt.show()

# %% [markdown]
# <h1>Degree = 5 </h1>

# %%
polyreg = PolynomialFeatures(degree=5)
x_poly = polyreg.fit_transform(X)
linreg2 = LinearRegression()
linreg2.fit(x_poly, y)
y_predict = linreg2.predict(x_poly)
print(x_poly)
# Out:
# [[1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00 1.0000e+00]
#  [1.0000e+00 2.0000e+00 4.0000e+00 8.0000e+00 1.6000e+01 3.2000e+01]
#  [1.0000e+00 3.0000e+00 9.0000e+00 2.7000e+01 8.1000e+01 2.4300e+02]
#  [1.0000e+00 4.0000e+00 1.6000e+01 6.4000e+01 2.5600e+02 1.0240e+03]
#  [1.0000e+00 5.0000e+00 2.5000e+01 1.2500e+02 6.2500e+02 3.1250e+03]
#  [1.0000e+00 6.0000e+00 3.6000e+01 2.1600e+02 1.2960e+03 7.7760e+03]
#  [1.0000e+00 7.0000e+00 4.9000e+01 3.4300e+02 2.4010e+03 1.6807e+04]
#  [1.0000e+00 8.0000e+00 6.4000e+01 5.1200e+02 4.0960e+03 3.2768e+04]
#  [1.0000e+00 9.0000e+00 8.1000e+01 7.2900e+02 6.5610e+03 5.9049e+04]
#  [1.0000e+00 1.0000e+01 1.0000e+02 1.0000e+03 1.0000e+04 1.0000e+05]]

# %%
## Coefficients
b0, b1, b2, b3, b4, b5 = linreg2.coef_[0:]
print("b0 : ", b0)
print("b1 : ", b1)
print("b2 : ", b2)
print("b3 : ", b3)
print("b4 : ", b4)
print("b5 : ", b5)
# Out:
# b0 :  0.0
# b1 :  160731.00232692368
# b2 :  -100378.78787689965
# b3 :  28164.91841454394
# b4 :  -3446.386946353836
# b5 :  157.69230769120622

# %%
plt.scatter(X, y, color = "blue")
plt.plot(X, y_predict, color = "red")
plt.title("Polynomial Regression")
plt.ylabel("Salary")
plt.xlabel("Position Levels")
plt.grid()
plt.show()
